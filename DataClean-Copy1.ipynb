# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('input.csv')

# %%
data.head()
# Out:
#        A_1      A_2      A_3   B_1  B_2  B_3     X_1      X_2  X_3  E_g  \
# 0   Cs/.25  MA/0.75  FA/0.75  Pb/1  NaN  NaN  I/0.83  Br/0.17  NaN  NaN
# 1   Cs/.25  MA/0.75  FA/0.75  Pb/1  NaN  NaN  I/0.83  Br/0.17  NaN  NaN
# 2  Cs/0.21  MA/0.79  FA/0.75  Pb/1  NaN  NaN  I/0.83  Br/0.17  NaN  NaN
# 3  Cs/0.21  MA/0.79  FA/0.75  Pb/1  NaN  NaN  I/0.83  Br/0.17  NaN  NaN
# 4  Cs/0.15  MA/0.85  FA/0.75  Pb/1  NaN  NaN  I/0.83  Br/0.17  NaN  NaN
#
#             HTL   ETL  Voc(volts)    Jsc  Max PCE
# 0  spiro-OMeTAD  TiO2        1.045  20.7     14.3
# 1  spiro-OMeTAD  TiO2        1.021  20.9     12.4
# 2  spiro-OMeTAD  TiO2        1.054  20.4     15.9
# 3  spiro-OMeTAD  TiO2        1.022  20.7     15.2
# 4  spiro-OMeTAD  TiO2        1.050  20.9     16.0

# %%
data1 = pd.DataFrame()

# %%
data1['A1'], data1['A1_ratio'] = data['A_1'].str.split('/',1).str
data1['A2'], data1['A2_ratio'] = data['A_2'].str.split('/',1).str
data1['A3'], data1['A3_ratio'] = data['A_3'].str.split('/',1).str
data1['B1'], data1['B1_ratio'] = data['B_1'].str.split('/',1).str
data1['B2'], data1['B2_ratio'] = data['B_2'].str.split('/',1).str
data1['X1'], data1['X1_ratio'] = data['X_1'].str.split('/',1).str
data1['X2'], data1['X2_ratio'] = data['X_2'].str.split('/',1).str
data1['PCE'] =data['Max PCE']

# %%
data1['A1_ratio'].convert_objects(convert_numeric=True)
data1['A2_ratio'].convert_objects(convert_numeric=True)
data1['A3_ratio'].convert_objects(convert_numeric=True)
data1['B1_ratio'].convert_objects(convert_numeric=True)
data1['B2_ratio'].convert_objects(convert_numeric=True)
data1['X1_ratio'].convert_objects(convert_numeric=True)
data1['X2_ratio'].convert_objects(convert_numeric=True)
# Out:
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:8: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# 0      0.170
# 1      0.170
# 2      0.170
# 3      0.170
# 4      0.170
# 5      0.170
# 6      0.170
# 7      0.170
# 8      0.170
# 9      0.170
# 10     0.170
# 11     0.170
# 12     0.170
# 13     0.170
# 14     0.170
# 15     0.170
# 16     0.170
# 17     0.170
# 18     0.170
# 19     0.170
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26     0.400
# 27       NaN
# 28     0.030
# 29     0.110
#        ...
# 221    0.833
# 222    0.833
# 223    0.833
# 224    1.000
# 225    1.000
# 226    1.000
# 227    1.000
# 228    1.000
# 229    1.000
# 230    1.000
# 231      NaN
# 232      NaN
# 233      NaN
# 234      NaN
# 235      NaN
# 236      NaN
# 237      NaN
# 238      NaN
# 239      NaN
# 240      NaN
# 241      NaN
# 242    0.167
# 243      NaN
# 244      NaN
# 245      NaN
# 246      NaN
# 247      NaN
# 248      NaN
# 249    0.400
# 250    0.667
# Name: X2_ratio, dtype: float64

# %%
data1 = data1.fillna(0)

# %%
data1
# Out:
#        A1 A1_ratio  A2 A2_ratio  A3 A3_ratio  B1 B1_ratio  B2 B2_ratio X1  \
# 0      Cs      .25  MA     0.75  FA     0.75  Pb        1   0        0  I
# 1      Cs      .25  MA     0.75  FA     0.75  Pb        1   0        0  I
# 2      Cs     0.21  MA     0.79  FA     0.75  Pb        1   0        0  I
# 3      Cs     0.21  MA     0.79  FA     0.75  Pb        1   0        0  I
# 4      Cs     0.15  MA     0.85  FA     0.75  Pb        1   0        0  I
# 5      Cs     0.15  MA     0.85  FA     0.75  Pb        1   0        0  I
# 6      Cs     0.10  MA     0.90  FA     0.75  Pb        1   0        0  I
# 7      Cs     0.10  MA     0.90  FA     0.75  Pb        1   0        0  I
# 8      Cs     0.05  MA     0.95  FA     0.75  Pb        1   0        0  I
# 9       0        0  MA      1.0  FA     0.75  Pb        1   0        0  I
# 10     Cs      .17  MA     0.83  FA     0.83  Pb        1   0        0  I
# 11     Cs      .17  MA     0.83  FA     0.83  Pb        1   0        0  I
# 12     Cs      .14  MA     0.86  FA     0.83  Pb        1   0        0  I
# 13     Cs      .14  MA     0.86  FA     0.83  Pb        1   0        0  I
# 14     Cs      .10  MA     0.90  FA     0.83  Pb        1   0        0  I
# 15     Cs      .10  MA     0.90  FA     0.83  Pb        1   0        0  I
# 16     Cs      .05  MA     0.95  FA     0.83  Pb        1   0        0  I
# 17     Cs      .05  MA     0.95  FA     0.83  Pb        1   0        0  I
# 18      0        0  MA      1.0  FA     0.83  Pb        1   0        0  I
# 19      0        0  MA      1.0  FA     0.83  Pb        1   0        0  I
# 20      0        0  MA      1.0   0        0  Pb        1   0        0  I
# 21   Al3+    0.075  MA      1.0   0        0  Pb        1   0        0  I
# 22   Al3+     0.15  MA      1.0   0        0  Pb        1   0        0  I
# 23   Al3+      0.3  MA      1.0   0        0  Pb        1   0        0  I
# 24   Al3+     0.75  MA      1.0   0        0  Pb        1   0        0  I
# 25   Al3+      1.5  MA      1.0   0        0  Pb        1   0        0  I
# 26     FA     0.83  Cs     0.17   0        0  Pb        1   0        0  I
# 27     MA      1.0   0        0   0        0  Pb        1   0        0  I
# 28     MA      1.0   0        0   0        0  Pb        1   0        0  I
# 29     MA      1.0   0        0   0        0  Pb        1   0        0  I
# ..    ...      ...  ..      ...  ..      ...  ..      ...  ..      ... ..
# 221    FA    0.333  MA    0.667   0        0  Pb        1   0        0  I
# 222    FA    0.167  MA    0.167   0        0  Pb        1   0        0  I
# 223    FA      0.0  MA        1   0        0  Pb        1   0        0  I
# 224    FA        1  MA        0   0        0  Pb        1   0        0  I
# 225    FA    0.833  MA    0.167   0        0  Pb        1   0        0  I
# 226    FA    0.667  MA    0.333   0        0  Pb        1   0        0  I
# 227    FA     0.50  MA     0.50   0        0  Pb        1   0        0  I
# 228    FA    0.333  MA    0.667   0        0  Pb        1   0        0  I
# 229    FA    0.167  MA    0.167   0        0  Pb        1   0        0  I
# 230    FA      0.0  MA        1   0        0  Pb        1   0        0  I
# 231    FA        0  MA      1.0   0        0  Pb     0.75  Sn     0.25  I
# 232    FA     0.25  MA     0.75   0        0  Pb     0.75  Sn     0.25  I
# 233    FA     0.50  MA     0.50   0        0  Pb     0.75  Sn     0.25  I
# 234    FA     0.75  MA     0.25   0        0  Pb     0.75  Sn     0.25  I
# 235    FA      1.0  FA      0.0   0        0  Pb     0.75  Sn     0.25  I
# 236    MA      1.0   0        0   0        0  Pb      1.0  Sn      0.0  I
# 237    MA      1.0   0        0   0        0  Pb     0.75  Sn     0.25  I
# 238    MA      1.0   0        0   0        0  Pb     0.50  Sn     0.50  I
# 239    MA      1.0   0        0   0        0  Pb     0.25  Sn     0.75  I
# 240    MA      1.0   0        0   0        0  Pb      0.0  Sn      1.0  I
# 241    MA      0.5  FA      0.5   0        0  Pb     0.50  Sn     0.50  I
# 242    MA      1.0   0        0   0        0  Pb    0.833  Sr    0.167  I
# 243    MA      1.0  Ag      0.0   0        0  Pb      1.0   0        0  I
# 244    MA    0.995  Ag    0.005   0        0  Pb      1.0   0        0  I
# 245    MA    0.990  Ag     0.01   0        0  Pb      1.0   0        0  I
# 246    MA    0.975  Ag    0.025   0        0  Pb      1.0   0        0  I
# 247    MA     0.95  Ag     0.05   0        0  Pb      1.0   0        0  I
# 248    MA      1.0   0        0   0        0  Pb      1.0   0        0  I
# 249    MA      1.0   0        0   0        0  Pb      1.0   0        0  I
# 250    MA      1.0   0        0   0        0  Pb      1.0   0        0  I
#
#     X1_ratio  X2 X2_ratio    PCE
# 0       0.83  Br     0.17  14.30
# 1       0.83  Br     0.17  12.40
# 2       0.83  Br     0.17  15.90
# 3       0.83  Br     0.17  15.20
# 4       0.83  Br     0.17  16.00
# 5       0.83  Br     0.17  16.80
# 6       0.83  Br     0.17  14.90
# 7       0.83  Br     0.17  16.30
# 8       0.83  Br     0.17   8.50
# 9       0.83  Br     0.17  10.10
# 10      0.83  Br     0.17  15.80
# 11      0.83  Br     0.17  15.40
# 12      0.83  Br     0.17  16.00
# 13      0.83  Br     0.17  16.30
# 14      0.83  Br     0.17  16.20
# 15      0.83  Br     0.17  16.20
# 16      0.83  Br     0.17  14.60
# 17      0.83  Br     0.17  15.50
# 18      0.83  Br     0.17  13.40
# 19      0.83  Br     0.17  12.90
# 20       1.0   0        0  13.20
# 21       1.0   0        0  13.60
# 22       1.0   0        0  15.80
# 23       1.0   0        0  14.20
# 24       1.0   0        0   9.80
# 25       1.0   0        0   5.50
# 26       0.6  Br      0.4  16.80
# 27       1.0   0        0   7.50
# 28      0.97   I     0.03  11.20
# 29      0.89   I     0.11  15.80
# ..       ...  ..      ...    ...
# 221    0.167  Br    0.833   2.90
# 222    0.167  Br    0.833   2.30
# 223    0.167  Br    0.833   3.50
# 224        0  Br      1.0   5.00
# 225        0  Br      1.0   6.50
# 226        0  Br      1.0   5.50
# 227        0  Br      1.0   7.10
# 228        0  Br      1.0   6.40
# 229        0  Br      1.0   7.10
# 230        0  Br      1.0   5.60
# 231        1   0        0  14.35
# 232        1   0        0  13.87
# 233        1   0        0  14.19
# 234        1   0        0   7.53
# 235        1   0        0   7.32
# 236        1   0        0  14.07
# 237        1   0        0  14.35
# 238        1   0        0   3.68
# 239        1   0        0   2.36
# 240        1   0        0   0.26
# 241      1.0   0        0  14.01
# 242    0.833  Cl    0.167  15.90
# 243      1.0   0        0  16.00
# 244      1.0   0        0  18.40
# 245      1.0   0        0  17.90
# 246      1.0   0        0  15.20
# 247      1.0   0        0  13.00
# 248      1.0   0        0   3.85
# 249      0.6  Cl      0.4   6.15
# 250    0.333  Cl    0.667   3.85
#
# [251 rows x 15 columns]

# %%
data1['A_sum'] = data1['A1_ratio'].convert_objects(convert_numeric=True)+data1['A2_ratio'].convert_objects(convert_numeric=True)+data1['A3_ratio'].convert_objects(convert_numeric=True)
data1['B_sum'] = data1['B1_ratio'].convert_objects(convert_numeric=True)+data1['B2_ratio'].convert_objects(convert_numeric=True)
data1['X_sum'] = data1['X1_ratio'].convert_objects(convert_numeric=True)+data1['X2_ratio'].convert_objects(convert_numeric=True)
# Out:
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# /Users/SarahsAdventure/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()

# %%
data1
# Out:
#        A1 A1_ratio  A2 A2_ratio  A3 A3_ratio  B1 B1_ratio  B2 B2_ratio X1  \
# 0      Cs      .25  MA     0.75  FA     0.75  Pb        1   0        0  I
# 1      Cs      .25  MA     0.75  FA     0.75  Pb        1   0        0  I
# 2      Cs     0.21  MA     0.79  FA     0.75  Pb        1   0        0  I
# 3      Cs     0.21  MA     0.79  FA     0.75  Pb        1   0        0  I
# 4      Cs     0.15  MA     0.85  FA     0.75  Pb        1   0        0  I
# 5      Cs     0.15  MA     0.85  FA     0.75  Pb        1   0        0  I
# 6      Cs     0.10  MA     0.90  FA     0.75  Pb        1   0        0  I
# 7      Cs     0.10  MA     0.90  FA     0.75  Pb        1   0        0  I
# 8      Cs     0.05  MA     0.95  FA     0.75  Pb        1   0        0  I
# 9       0        0  MA      1.0  FA     0.75  Pb        1   0        0  I
# 10     Cs      .17  MA     0.83  FA     0.83  Pb        1   0        0  I
# 11     Cs      .17  MA     0.83  FA     0.83  Pb        1   0        0  I
# 12     Cs      .14  MA     0.86  FA     0.83  Pb        1   0        0  I
# 13     Cs      .14  MA     0.86  FA     0.83  Pb        1   0        0  I
# 14     Cs      .10  MA     0.90  FA     0.83  Pb        1   0        0  I
# 15     Cs      .10  MA     0.90  FA     0.83  Pb        1   0        0  I
# 16     Cs      .05  MA     0.95  FA     0.83  Pb        1   0        0  I
# 17     Cs      .05  MA     0.95  FA     0.83  Pb        1   0        0  I
# 18      0        0  MA      1.0  FA     0.83  Pb        1   0        0  I
# 19      0        0  MA      1.0  FA     0.83  Pb        1   0        0  I
# 20      0        0  MA      1.0   0        0  Pb        1   0        0  I
# 21   Al3+    0.075  MA      1.0   0        0  Pb        1   0        0  I
# 22   Al3+     0.15  MA      1.0   0        0  Pb        1   0        0  I
# 23   Al3+      0.3  MA      1.0   0        0  Pb        1   0        0  I
# 24   Al3+     0.75  MA      1.0   0        0  Pb        1   0        0  I
# 25   Al3+      1.5  MA      1.0   0        0  Pb        1   0        0  I
# 26     FA     0.83  Cs     0.17   0        0  Pb        1   0        0  I
# 27     MA      1.0   0        0   0        0  Pb        1   0        0  I
# 28     MA      1.0   0        0   0        0  Pb        1   0        0  I
# 29     MA      1.0   0        0   0        0  Pb        1   0        0  I
# ..    ...      ...  ..      ...  ..      ...  ..      ...  ..      ... ..
# 221    FA    0.333  MA    0.667   0        0  Pb        1   0        0  I
# 222    FA    0.167  MA    0.167   0        0  Pb        1   0        0  I
# 223    FA      0.0  MA        1   0        0  Pb        1   0        0  I
# 224    FA        1  MA        0   0        0  Pb        1   0        0  I
# 225    FA    0.833  MA    0.167   0        0  Pb        1   0        0  I
# 226    FA    0.667  MA    0.333   0        0  Pb        1   0        0  I
# 227    FA     0.50  MA     0.50   0        0  Pb        1   0        0  I
# 228    FA    0.333  MA    0.667   0        0  Pb        1   0        0  I
# 229    FA    0.167  MA    0.167   0        0  Pb        1   0        0  I
# 230    FA      0.0  MA        1   0        0  Pb        1   0        0  I
# 231    FA        0  MA      1.0   0        0  Pb     0.75  Sn     0.25  I
# 232    FA     0.25  MA     0.75   0        0  Pb     0.75  Sn     0.25  I
# 233    FA     0.50  MA     0.50   0        0  Pb     0.75  Sn     0.25  I
# 234    FA     0.75  MA     0.25   0        0  Pb     0.75  Sn     0.25  I
# 235    FA      1.0  FA      0.0   0        0  Pb     0.75  Sn     0.25  I
# 236    MA      1.0   0        0   0        0  Pb      1.0  Sn      0.0  I
# 237    MA      1.0   0        0   0        0  Pb     0.75  Sn     0.25  I
# 238    MA      1.0   0        0   0        0  Pb     0.50  Sn     0.50  I
# 239    MA      1.0   0        0   0        0  Pb     0.25  Sn     0.75  I
# 240    MA      1.0   0        0   0        0  Pb      0.0  Sn      1.0  I
# 241    MA      0.5  FA      0.5   0        0  Pb     0.50  Sn     0.50  I
# 242    MA      1.0   0        0   0        0  Pb    0.833  Sr    0.167  I
# 243    MA      1.0  Ag      0.0   0        0  Pb      1.0   0        0  I
# 244    MA    0.995  Ag    0.005   0        0  Pb      1.0   0        0  I
# 245    MA    0.990  Ag     0.01   0        0  Pb      1.0   0        0  I
# 246    MA    0.975  Ag    0.025   0        0  Pb      1.0   0        0  I
# 247    MA     0.95  Ag     0.05   0        0  Pb      1.0   0        0  I
# 248    MA      1.0   0        0   0        0  Pb      1.0   0        0  I
# 249    MA      1.0   0        0   0        0  Pb      1.0   0        0  I
# 250    MA      1.0   0        0   0        0  Pb      1.0   0        0  I
#
#     X1_ratio  X2 X2_ratio    PCE  A_sum  B_sum  X_sum
# 0       0.83  Br     0.17  14.30  1.750    1.0    1.0
# 1       0.83  Br     0.17  12.40  1.750    1.0    1.0
# 2       0.83  Br     0.17  15.90  1.750    1.0    1.0
# 3       0.83  Br     0.17  15.20  1.750    1.0    1.0
# 4       0.83  Br     0.17  16.00  1.750    1.0    1.0
# 5       0.83  Br     0.17  16.80  1.750    1.0    1.0
# 6       0.83  Br     0.17  14.90  1.750    1.0    1.0
# 7       0.83  Br     0.17  16.30  1.750    1.0    1.0
# 8       0.83  Br     0.17   8.50  1.750    1.0    1.0
# 9       0.83  Br     0.17  10.10  1.750    1.0    1.0
# 10      0.83  Br     0.17  15.80  1.830    1.0    1.0
# 11      0.83  Br     0.17  15.40  1.830    1.0    1.0
# 12      0.83  Br     0.17  16.00  1.830    1.0    1.0
# 13      0.83  Br     0.17  16.30  1.830    1.0    1.0
# 14      0.83  Br     0.17  16.20  1.830    1.0    1.0
# 15      0.83  Br     0.17  16.20  1.830    1.0    1.0
# 16      0.83  Br     0.17  14.60  1.830    1.0    1.0
# 17      0.83  Br     0.17  15.50  1.830    1.0    1.0
# 18      0.83  Br     0.17  13.40  1.830    1.0    1.0
# 19      0.83  Br     0.17  12.90  1.830    1.0    1.0
# 20       1.0   0        0  13.20  1.000    1.0    1.0
# 21       1.0   0        0  13.60  1.075    1.0    1.0
# 22       1.0   0        0  15.80  1.150    1.0    1.0
# 23       1.0   0        0  14.20  1.300    1.0    1.0
# 24       1.0   0        0   9.80  1.750    1.0    1.0
# 25       1.0   0        0   5.50  2.500    1.0    1.0
# 26       0.6  Br      0.4  16.80  1.000    1.0    1.0
# 27       1.0   0        0   7.50  1.000    1.0    1.0
# 28      0.97   I     0.03  11.20  1.000    1.0    1.0
# 29      0.89   I     0.11  15.80  1.000    1.0    1.0
# ..       ...  ..      ...    ...    ...    ...    ...
# 221    0.167  Br    0.833   2.90  1.000    1.0    1.0
# 222    0.167  Br    0.833   2.30  0.334    1.0    1.0
# 223    0.167  Br    0.833   3.50  1.000    1.0    1.0
# 224        0  Br      1.0   5.00  1.000    1.0    1.0
# 225        0  Br      1.0   6.50  1.000    1.0    1.0
# 226        0  Br      1.0   5.50  1.000    1.0    1.0
# 227        0  Br      1.0   7.10  1.000    1.0    1.0
# 228        0  Br      1.0   6.40  1.000    1.0    1.0
# 229        0  Br      1.0   7.10  0.334    1.0    1.0
# 230        0  Br      1.0   5.60  1.000    1.0    1.0
# 231        1   0        0  14.35  1.000    1.0    1.0
# 232        1   0        0  13.87  1.000    1.0    1.0
# 233        1   0        0  14.19  1.000    1.0    1.0
# 234        1   0        0   7.53  1.000    1.0    1.0
# 235        1   0        0   7.32  1.000    1.0    1.0
# 236        1   0        0  14.07  1.000    1.0    1.0
# 237        1   0        0  14.35  1.000    1.0    1.0
# 238        1   0        0   3.68  1.000    1.0    1.0
# 239        1   0        0   2.36  1.000    1.0    1.0
# 240        1   0        0   0.26  1.000    1.0    1.0
# 241      1.0   0        0  14.01  1.000    1.0    1.0
# 242    0.833  Cl    0.167  15.90  1.000    1.0    1.0
# 243      1.0   0        0  16.00  1.000    1.0    1.0
# 244      1.0   0        0  18.40  1.000    1.0    1.0
# 245      1.0   0        0  17.90  1.000    1.0    1.0
# 246      1.0   0        0  15.20  1.000    1.0    1.0
# 247      1.0   0        0  13.00  1.000    1.0    1.0
# 248      1.0   0        0   3.85  1.000    1.0    1.0
# 249      0.6  Cl      0.4   6.15  1.000    1.0    1.0
# 250    0.333  Cl    0.667   3.85  1.000    1.0    1.0
#
# [251 rows x 18 columns]

# %%
data1.loc[data1['A_sum']!=1]
# Out:
#        A1 A1_ratio  A2 A2_ratio  A3 A3_ratio  B1 B1_ratio B2 B2_ratio X1  \
# 0      Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I
# 1      Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I
# 2      Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I
# 3      Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I
# 4      Cs     0.15  MA     0.85  FA     0.75  Pb        1  0        0  I
# 5      Cs     0.15  MA     0.85  FA     0.75  Pb        1  0        0  I
# 6      Cs     0.10  MA     0.90  FA     0.75  Pb        1  0        0  I
# 7      Cs     0.10  MA     0.90  FA     0.75  Pb        1  0        0  I
# 8      Cs     0.05  MA     0.95  FA     0.75  Pb        1  0        0  I
# 9       0        0  MA      1.0  FA     0.75  Pb        1  0        0  I
# 10     Cs      .17  MA     0.83  FA     0.83  Pb        1  0        0  I
# 11     Cs      .17  MA     0.83  FA     0.83  Pb        1  0        0  I
# 12     Cs      .14  MA     0.86  FA     0.83  Pb        1  0        0  I
# 13     Cs      .14  MA     0.86  FA     0.83  Pb        1  0        0  I
# 14     Cs      .10  MA     0.90  FA     0.83  Pb        1  0        0  I
# 15     Cs      .10  MA     0.90  FA     0.83  Pb        1  0        0  I
# 16     Cs      .05  MA     0.95  FA     0.83  Pb        1  0        0  I
# 17     Cs      .05  MA     0.95  FA     0.83  Pb        1  0        0  I
# 18      0        0  MA      1.0  FA     0.83  Pb        1  0        0  I
# 19      0        0  MA      1.0  FA     0.83  Pb        1  0        0  I
# 21   Al3+    0.075  MA      1.0   0        0  Pb        1  0        0  I
# 22   Al3+     0.15  MA      1.0   0        0  Pb        1  0        0  I
# 23   Al3+      0.3  MA      1.0   0        0  Pb        1  0        0  I
# 24   Al3+     0.75  MA      1.0   0        0  Pb        1  0        0  I
# 25   Al3+      1.5  MA      1.0   0        0  Pb        1  0        0  I
# 32     FA     0.95  Ma      0.5   0        0  Pb        1  0        0  I
# 68     FA     0.81  MA     0.15   0        0  Pb      1.0  0        0  I
# 69     FA     0.81  MA     0.15   0        0  Pb      1.0  0        0  I
# 105    Al  0.00075  MA  0.99775   0        0  Pb        1  0        0  I
# 106    Al   0.0015  MA   0.9955   0        0  Pb        1  0        0  I
# 107    Al    0.003  MA    0.991   0        0  Pb        1  0        0  I
# 108    Al   0.0075  MA   0.9775   0        0  Pb        1  0        0  I
# 109    Al    0.015  MA    0.955   0        0  Pb        1  0        0  I
# 170    FA      0.9  Cs     0.17   0        0  Pb        1  0        0  I
# 175    FA     0.83  Cs      0.2   0        0  Pb        1  0        0  I
# 187    FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 194    FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 201    FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 208    FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 215    FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 222    FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 229    FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
#
#     X1_ratio  X2 X2_ratio   PCE   A_sum  B_sum  X_sum
# 0       0.83  Br     0.17  14.3  1.7500    1.0  1.000
# 1       0.83  Br     0.17  12.4  1.7500    1.0  1.000
# 2       0.83  Br     0.17  15.9  1.7500    1.0  1.000
# 3       0.83  Br     0.17  15.2  1.7500    1.0  1.000
# 4       0.83  Br     0.17  16.0  1.7500    1.0  1.000
# 5       0.83  Br     0.17  16.8  1.7500    1.0  1.000
# 6       0.83  Br     0.17  14.9  1.7500    1.0  1.000
# 7       0.83  Br     0.17  16.3  1.7500    1.0  1.000
# 8       0.83  Br     0.17   8.5  1.7500    1.0  1.000
# 9       0.83  Br     0.17  10.1  1.7500    1.0  1.000
# 10      0.83  Br     0.17  15.8  1.8300    1.0  1.000
# 11      0.83  Br     0.17  15.4  1.8300    1.0  1.000
# 12      0.83  Br     0.17  16.0  1.8300    1.0  1.000
# 13      0.83  Br     0.17  16.3  1.8300    1.0  1.000
# 14      0.83  Br     0.17  16.2  1.8300    1.0  1.000
# 15      0.83  Br     0.17  16.2  1.8300    1.0  1.000
# 16      0.83  Br     0.17  14.6  1.8300    1.0  1.000
# 17      0.83  Br     0.17  15.5  1.8300    1.0  1.000
# 18      0.83  Br     0.17  13.4  1.8300    1.0  1.000
# 19      0.83  Br     0.17  12.9  1.8300    1.0  1.000
# 21       1.0   0        0  13.6  1.0750    1.0  1.000
# 22       1.0   0        0  15.8  1.1500    1.0  1.000
# 23       1.0   0        0  14.2  1.3000    1.0  1.000
# 24       1.0   0        0   9.8  1.7500    1.0  1.000
# 25       1.0   0        0   5.5  2.5000    1.0  1.000
# 32      0.95  Br      0.5  10.1  1.4500    1.0  1.450
# 68     0.836  Br     0.15  16.1  0.9600    1.0  0.986
# 69     0.836  Br     0.15  17.2  0.9600    1.0  0.986
# 105        1   0        0  16.4  0.9985    1.0  1.000
# 106        1   0        0  18.2  0.9970    1.0  1.000
# 107        1   0        0  16.6  0.9940    1.0  1.000
# 108        1   0        0  11.7  0.9850    1.0  1.000
# 109        1   0        0   6.7  0.9700    1.0  1.000
# 170      0.6  Br      0.4  12.1  1.0700    1.0  1.000
# 175      0.6  Br      0.4  10.5  1.0300    1.0  1.000
# 187        1  Br        0  11.8  0.3340    1.0  1.000
# 194    0.833  Br    0.167  16.0  0.3340    1.0  1.000
# 201    0.667  Br    0.333  12.2  0.3340    1.0  1.000
# 208      0.5  Br      0.5   8.7  0.3340    1.0  1.000
# 215    0.333  Br    0.667   3.5  0.3340    1.0  1.000
# 222    0.167  Br    0.833   2.3  0.3340    1.0  1.000
# 229        0  Br      1.0   7.1  0.3340    1.0  1.000

# %%
data1.loc[data1['B_sum']!=1]
# Out:
# Empty DataFrame
# Columns: [A1, A1_ratio, A2, A2_ratio, A3, A3_ratio, B1, B1_ratio, B2, B2_ratio, X1, X1_ratio, X2, X2_ratio, PCE, A_sum, B_sum, X_sum]
# Index: []

# %%
data1.loc[data1['X_sum']!=1]
# Out:
#          A1 A1_ratio  A2 A2_ratio A3 A3_ratio  B1 B1_ratio  B2 B2_ratio  X1  \
# 32       FA     0.95  Ma      0.5  0        0  Pb        1   0        0   I
# 37       MA      1.0   0        0  0        0  Pb     0.97  Sn     0.03   I
# 38       MA      1.0   0        0  0        0  PB     0.95  Sn     0.05   I
# 39       MA      1.0   0        0  0        0  PB     0.90  Sn     0.10   I
# 40       Ma     0.95  Cs     0.05  0        0  Pb     0.95  Sn     0.05   I
# 41       MA     0.90  Cs     0.10  0        0  Pb     0.90  Sn     0.10   I
# 42       Ma     0.95  Cs     0.05  0        0  Pb     0.95  Sn     0.05   I
# 43       MA     0.90  Cs     0.10  0        0  Pb     0.90  Sn     0.10   I
# 49       MA      1.0  Cs      0.0  0        0  Pb      1.0   0        0   I
# 65       FA     0.95  Cs     0.05  0        0  Pb      1.0   0        0   I
# 66       FA     0.90  Cs     0.10  0        0  Pb      1.0   0        0   I
# 67       FA     0.85  Cs     0.15  0        0  Pb      1.0   0        0   I
# 68       FA     0.81  MA     0.15  0        0  Pb      1.0   0        0   I
# 69       FA     0.81  MA     0.15  0        0  Pb      1.0   0        0   I
# 82   CH3NH3        1   0        0  0        0  Pb     0.97  Sb     0.03   I
# 110      MA        1   0        0  0        0  Pb        1   0        0   I
# 179      FA        1   0        0  0        0  Pb        1   0        0  I1
#
#     X1_ratio   X2 X2_ratio    PCE  A_sum  B_sum   X_sum
# 32      0.95   Br      0.5  10.10   1.45    1.0  1.4500
# 37      2.94   Br     0.06   5.24   1.00    1.0  3.0000
# 38      2.90   Br     0.10   7.59   1.00    1.0  3.0000
# 39      2.80   Br     0.20   4.74   1.00    1.0  3.0000
# 40      2.90   Br     0.10   8.25   1.00    1.0  3.0000
# 41      2.80   Br     0.20   6.50   1.00    1.0  3.0000
# 42      2.85   Br     0.15   6.50   1.00    1.0  3.0000
# 43      2.70   Br     0.30   5.94   1.00    1.0  3.0000
# 49       1.0   Br      1.0  14.50   1.00    1.0  2.0000
# 65    0.9625  SCN   0.0376  10.50   1.00    1.0  1.0001
# 66    0.9625  SCN   0.0377  11.10   1.00    1.0  1.0002
# 67    0.9625  SCN   0.0378   3.50   1.00    1.0  1.0003
# 68     0.836   Br     0.15  16.10   0.96    1.0  0.9860
# 69     0.836   Br     0.15  17.20   0.96    1.0  0.9860
# 82      0.98   Br     0.03   6.47   1.00    1.0  1.0100
# 110        3   Br        0  15.60   1.00    1.0  3.0000
# 179        0    0        0  10.40   1.00    1.0  0.0000

# %%
Cl = {'IR':181, 'EA':3.61, 'IE':12.97, 'IP':16.0858, 'AP':11.5582}
Br = {'IR':196, 'EA':3.36, 'IE':11.81, 'IP':20.5166, 'AP':15.4074}
I = {'IR':220, 'EA':3.06, 'IE':10.45, 'IP':43.2951, 'AP':28.8659}
Al = {'IR': 53.5, 'EA':0.43, 'IE':5.99, 'IP':25.6499, 'AP':46.2}
Cs = {'IR':167, 'EA':0.47, 'IE':3.89, 'IP':15.544, 'AP':402}
Rb = {'IR':152, 'EA':0.486, 'IE':4.18, 'IP':9, 'AP':319}
Pb = {'IR':133, 'EA':0.37, 'IE':7.42, 'IP':13.8008, 'AP':47.1}
Sn = {'IR':83, 'EA':1.11, 'IE':7.34, 'IP':15.5813, 'AP':42.4}
Ge = {'IR':87, 'EA':1.23, 'IE':7.899, 'IP':11.3784, 'AP':30.9097}
Sr = {'IR':132, 'EA':0.05, 'IE':5.69, 'IP':5.792, 'AP':186}
Ni = {'IR':83, 'EA':1.16, 'IE':7.64, 'IP':0.0, 'AP':0.0} # missiing data
Mg = {'IR':86, 'EA':0.0, 'IE':7.65, 'IP':0.489, 'AP':71.33} # missiing data
Fe = {'IR':75, 'EA':0.31, 'IE':7.90, 'IP':0.0, 'AP':0.0} # missiing data
Cu = {'IR':87, 'EA':1.24, 'IE':7.73, 'IP':0.0, 'AP':41.65} # missiing data
Co = {'IR':79, 'EA':0.6633, 'IE':7.88, 'IP':0.0, 'AP':0.0} # missiing data
MA = {'IR':537, 'EA':0.80, 'IE':10.66, 'IP':19.7942, 'AP':25.1017}
FA = {'IR':641, 'EA':0.60, 'IE':10.03, 'IP':26.8527, 'AP':32.5342}
HA = {'IR':523, 'EA':0.89, 'IE':9.90, 'IP':17.4412, 'AP':22.566}

# %%
data1.dtypes
# Out:
# A1           object
# A1_ratio     object
# A2           object
# A2_ratio     object
# A3           object
# A3_ratio     object
# B1           object
# B1_ratio     object
# B2           object
# B2_ratio     object
# X1           object
# X1_ratio     object
# X2           object
# X2_ratio     object
# PCE         float64
# A_sum       float64
# B_sum       float64
# X_sum       float64
# dtype: object

# %%
volume = []
radii = []
Cl = {'IR':181, 'EA':3.61, 'IE':12.97, 'IP':16.0858, 'AP':11.5582}
Br = {'IR':196, 'EA':3.36, 'IE':11.81, 'IP':20.5166, 'AP':15.4074}
I = {'IR':220, 'EA':3.06, 'IE':10.45, 'IP':43.2951, 'AP':28.8659}
Al = {'IR': 53.5, 'EA':0.43, 'IE':5.99, 'IP':25.6499, 'AP':46.2}
Cs = {'IR':167, 'EA':0.47, 'IE':3.89, 'IP':15.544, 'AP':402}
Rb = {'IR':152, 'EA':0.486, 'IE':4.18, 'IP':9, 'AP':319}
Pb = {'IR':133, 'EA':0.37, 'IE':7.42, 'IP':13.8008, 'AP':47.1}
Sn = {'IR':83, 'EA':1.11, 'IE':7.34, 'IP':15.5813, 'AP':42.4}
Ge = {'IR':87, 'EA':1.23, 'IE':7.899, 'IP':11.3784, 'AP':30.9097}
Sr = {'IR':132, 'EA':0.05, 'IE':5.69, 'IP':5.792, 'AP':186}
Ni = {'IR':83, 'EA':1.16, 'IE':7.64, 'IP':0.0, 'AP':0.0} # missiing data
Mg = {'IR':86, 'EA':0.0, 'IE':7.65, 'IP':0.489, 'AP':71.33} # missiing data
Fe = {'IR':75, 'EA':0.31, 'IE':7.90, 'IP':0.0, 'AP':0.0} # missiing data
Cu = {'IR':87, 'EA':1.24, 'IE':7.73, 'IP':0.0, 'AP':41.65} # missiing data
Co = {'IR':79, 'EA':0.6633, 'IE':7.88, 'IP':0.0, 'AP':0.0} # missiing data
MA = {'IR':537, 'EA':0.80, 'IE':10.66, 'IP':19.7942, 'AP':25.1017}
FA = {'IR':641, 'EA':0.60, 'IE':10.03, 'IP':26.8527, 'AP':32.5342}
HA = {'IR':523, 'EA':0.89, 'IE':9.90, 'IP':17.4412, 'AP':22.566}
#for n in len(data1['A1']):
#    if data1['A1'] = 'FA'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-b9b135780b84> in <module>()
#       1 volume = []
#       2 radii = []
# ----> 3 radii['Cl'] = Cl.iloc[Cl['IR']]
#       4 print(Radius)
#       5 Cl = {'IR':181, 'EA':3.61, 'IE':12.97, 'IP':16.0858, 'AP':11.5582}
#
# AttributeError: 'dict' object has no attribute 'iloc'
