# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load input data
data = pd.read_csv('input2.csv')
data
# Out:
#           A_1       A_2      A_3   B_1  B_2  B_3      X_1       X_2  X_3  E_g  \
# 0      Cs/.25   MA/0.75  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 1      Cs/.25   MA/0.75  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 2     Cs/0.21   MA/0.79  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 3     Cs/0.21   MA/0.79  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 4     Cs/0.15   MA/0.85  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 5     Cs/0.15   MA/0.85  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 6     Cs/0.10   MA/0.90  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 7     Cs/0.10   MA/0.90  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 8     Cs/0.05   MA/0.95  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 9         NaN    MA/1.0  FA/0.75  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 10     Cs/.17   MA/0.83  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 11     Cs/.17   MA/0.83  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 12     Cs/.14   MA/0.86  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 13     Cs/.14   MA/0.86  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 14     Cs/.10   MA/0.90  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 15     Cs/.10   MA/0.90  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 16     Cs/.05   MA/0.95  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 17     Cs/.05   MA/0.95  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 18        NaN    MA/1.0  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 19        NaN    MA/1.0  FA/0.83  Pb/1  NaN  NaN   I/0.83   Br/0.17  NaN  NaN
# 20        NaN    MA/1.0      NaN  Pb/1  NaN  NaN    I/1.0       NaN  NaN  NaN
# 21   Al/0.075    MA/1.0      NaN  Pb/1  NaN  NaN    I/1.0       NaN  NaN  NaN
# 22    Al/0.15    MA/1.0      NaN  Pb/1  NaN  NaN    I/1.0       NaN  NaN  NaN
# 23     Al/0.3    MA/1.0      NaN  Pb/1  NaN  NaN    I/1.0       NaN  NaN  NaN
# 24    Al/0.75    MA/1.0      NaN  Pb/1  NaN  NaN    I/1.0       NaN  NaN  NaN
# 25     Al/1.5    MA/1.0      NaN  Pb/1  NaN  NaN    I/1.0       NaN  NaN  NaN
# 26    FA/0.83   Cs/0.17      NaN  Pb/1  NaN  NaN    I/0.6    Br/0.4  NaN  NaN
# 27     MA/1.0       NaN      NaN  Pb/1  NaN  NaN    I/1.0       NaN  NaN  NaN
# 28     MA/1.0       NaN      NaN  Pb/1  NaN  NaN   I/0.97    I/0.03  NaN  NaN
# 29     MA/1.0       NaN      NaN  Pb/1  NaN  NaN   I/0.89    I/0.11  NaN  NaN
# ..        ...       ...      ...   ...  ...  ...      ...       ...  ...  ...
# 192  FA/0.167  MA/0.167      NaN  Pb/1  NaN  NaN  I/0.667  Br/0.333  NaN  NaN
# 193    FA/0.0      MA/1      NaN  Pb/1  NaN  NaN  I/0.667  Br/0.333  NaN  NaN
# 194      FA/1      MA/0      NaN  Pb/1  NaN  NaN    I/0.5    Br/0.5  NaN  NaN
# 195  FA/0.833  MA/0.167      NaN  Pb/1  NaN  NaN    I/0.5    Br/0.5  NaN  NaN
# 196  FA/0.667  MA/0.333      NaN  Pb/1  NaN  NaN    I/0.5    Br/0.5  NaN  NaN
# 197   FA/0.50   MA/0.50      NaN  Pb/1  NaN  NaN    I/0.5    Br/0.5  NaN  NaN
# 198  FA/0.333  MA/0.667      NaN  Pb/1  NaN  NaN    I/0.5    Br/0.5  NaN  NaN
# 199  FA/0.167  MA/0.167      NaN  Pb/1  NaN  NaN    I/0.5    Br/0.5  NaN  NaN
# 200    FA/0.0      MA/1      NaN  Pb/1  NaN  NaN    I/0.5    Br/0.5  NaN  NaN
# 201      FA/1      MA/0      NaN  Pb/1  NaN  NaN  I/0.333  Br/0.667  NaN  NaN
# 202  FA/0.833  MA/0.167      NaN  Pb/1  NaN  NaN  I/0.333  Br/0.667  NaN  NaN
# 203  FA/0.667  MA/0.333      NaN  Pb/1  NaN  NaN  I/0.333  Br/0.667  NaN  NaN
# 204   FA/0.50   MA/0.50      NaN  Pb/1  NaN  NaN  I/0.333  Br/0.667  NaN  NaN
# 205  FA/0.333  MA/0.667      NaN  Pb/1  NaN  NaN  I/0.333  Br/0.667  NaN  NaN
# 206  FA/0.167  MA/0.167      NaN  Pb/1  NaN  NaN  I/0.333  Br/0.667  NaN  NaN
# 207    FA/0.0      MA/1      NaN  Pb/1  NaN  NaN  I/0.333  Br/0.667  NaN  NaN
# 208      FA/1      MA/0      NaN  Pb/1  NaN  NaN  I/0.167  Br/0.833  NaN  NaN
# 209  FA/0.833  MA/0.167      NaN  Pb/1  NaN  NaN  I/0.167  Br/0.833  NaN  NaN
# 210  FA/0.667  MA/0.333      NaN  Pb/1  NaN  NaN  I/0.167  Br/0.833  NaN  NaN
# 211   FA/0.50   MA/0.50      NaN  Pb/1  NaN  NaN  I/0.167  Br/0.833  NaN  NaN
# 212  FA/0.333  MA/0.667      NaN  Pb/1  NaN  NaN  I/0.167  Br/0.833  NaN  NaN
# 213  FA/0.167  MA/0.167      NaN  Pb/1  NaN  NaN  I/0.167  Br/0.833  NaN  NaN
# 214    FA/0.0      MA/1      NaN  Pb/1  NaN  NaN  I/0.167  Br/0.833  NaN  NaN
# 215      FA/1      MA/0      NaN  Pb/1  NaN  NaN      I/0    Br/1.0  NaN  NaN
# 216  FA/0.833  MA/0.167      NaN  Pb/1  NaN  NaN      I/0    Br/1.0  NaN  NaN
# 217  FA/0.667  MA/0.333      NaN  Pb/1  NaN  NaN      I/0    Br/1.0  NaN  NaN
# 218   FA/0.50   MA/0.50      NaN  Pb/1  NaN  NaN      I/0    Br/1.0  NaN  NaN
# 219  FA/0.333  MA/0.667      NaN  Pb/1  NaN  NaN      I/0    Br/1.0  NaN  NaN
# 220  FA/0.167  MA/0.167      NaN  Pb/1  NaN  NaN      I/0    Br/1.0  NaN  NaN
# 221    FA/0.0      MA/1      NaN  Pb/1  NaN  NaN      I/0    Br/1.0  NaN  NaN
#
#               HTL        ETL  Voc(volts)     Jsc  Max PCE
# 0    spiro-OMeTAD       TiO2        1.045  20.70     14.3
# 1    spiro-OMeTAD       TiO2        1.021  20.90     12.4
# 2    spiro-OMeTAD       TiO2        1.054  20.40     15.9
# 3    spiro-OMeTAD       TiO2        1.022  20.70     15.2
# 4    spiro-OMeTAD       TiO2        1.050  20.90     16.0
# 5    spiro-OMeTAD       TiO2        1.060  21.10     16.8
# 6    spiro-OMeTAD       TiO2        1.076  21.00     14.9
# 7    spiro-OMeTAD       TiO2        1.049  20.70     16.3
# 8    spiro-OMeTAD       TiO2        0.913  17.90      8.5
# 9    spiro-OMeTAD       TiO2        0.906  18.60     10.1
# 10   spiro-OMeTAD       TiO2        1.061  20.40     15.8
# 11   spiro-OMeTAD       TiO2        1.059  20.50     15.4
# 12   spiro-OMeTAD       TiO2        1.105  20.40     16.0
# 13   spiro-OMeTAD       TiO2        1.083  20.90     16.3
# 14   spiro-OMeTAD       TiO2        1.078  20.90     16.2
# 15   spiro-OMeTAD       TiO2        1.071  21.00     16.2
# 16   spiro-OMeTAD       TiO2        1.044  19.40     14.6
# 17   spiro-OMeTAD       TiO2        1.092  20.30     15.5
# 18   spiro-OMeTAD       TiO2        1.079  18.80     13.4
# 19   spiro-OMeTAD       TiO2        1.034  18.90     12.9
# 20            BCP   poly-TDP        1.010  19.00     13.2
# 21            BCP   poly-TDP        1.020  19.20     13.6
# 22            BCP   poly-TDP        1.060  21.20     15.8
# 23            BCP   poly-TDP        1.050  19.00     14.2
# 24            BCP   poly-TDP        0.990  15.30      9.8
# 25            BCP   poly-TDP        0.990   8.00      5.5
# 26   spiro-OMeTAD  Doped c60        1.060  22.10     16.8
# 27   spiro-OMeTAD      glass        0.880  18.42      7.5
# 28   spiro-OMeTAD      glass        0.970  18.96     11.2
# 29   spiro-OMeTAD      glass        1.010  22.38     15.8
# ..            ...        ...          ...    ...      ...
# 192           NaN        NaN        1.120  16.70     12.2
# 193           NaN        NaN        0.960  13.20      8.5
# 194           NaN        NaN        1.060   7.10      3.7
# 195           NaN        NaN        1.150  15.60     11.4
# 196           NaN        NaN        1.110  15.30     11.7
# 197           NaN        NaN        1.090  15.50     11.9
# 198           NaN        NaN        1.130  13.90     10.7
# 199           NaN        NaN        1.070  10.30      8.7
# 200           NaN        NaN        1.120   6.60      8.6
# 201           NaN        NaN        1.140  12.80      7.5
# 202           NaN        NaN        0.980  11.10      5.8
# 203           NaN        NaN        1.000   9.50      5.6
# 204           NaN        NaN        1.030  12.60      7.9
# 205           NaN        NaN        1.080   9.00      6.2
# 206           NaN        NaN        0.940   5.10      3.5
# 207           NaN        NaN        1.100   4.00      6.3
# 208           NaN        NaN        1.060   9.70      5.0
# 209           NaN        NaN        0.880   8.80      3.3
# 210           NaN        NaN        0.920   7.20      3.4
# 211           NaN        NaN        0.980   6.90      3.9
# 212           NaN        NaN        0.990   4.40      2.9
# 213           NaN        NaN        0.950   2.80      2.3
# 214           NaN        NaN        1.070   3.00      3.5
# 215           NaN        NaN        1.140   7.50      5.0
# 216           NaN        NaN        1.420   7.00      6.5
# 217           NaN        NaN        1.350   7.00      5.5
# 218           NaN        NaN        1.390   7.00      7.1
# 219           NaN        NaN        1.350   6.40      6.4
# 220           NaN        NaN        1.370   6.30      7.1
# 221           NaN        NaN        1.410   5.90      5.6
#
# [222 rows x 15 columns]

# %%
data1 = pd.DataFrame()

# %%
# split the element and its ratio
data1['A1'], data1['A1_ratio'] = data['A_1'].str.split('/',1).str
data1['A2'], data1['A2_ratio'] = data['A_2'].str.split('/',1).str
data1['A3'], data1['A3_ratio'] = data['A_3'].str.split('/',1).str
data1['B1'], data1['B1_ratio'] = data['B_1'].str.split('/',1).str
data1['B2'], data1['B2_ratio'] = data['B_2'].str.split('/',1).str
data1['X1'], data1['X1_ratio'] = data['X_1'].str.split('/',1).str
data1['X2'], data1['X2_ratio'] = data['X_2'].str.split('/',1).str
data1['PCE'] = data['Max PCE']

# %%
data1['A1_ratio'].head()
# Out:
# 0     .25
# 1     .25
# 2    0.21
# 3    0.21
# 4    0.15
# Name: A1_ratio, dtype: object

# %%
# convert all ratio from object to float
data1['A1_ratio'].convert_objects(convert_numeric=True)
data1['A2_ratio'].convert_objects(convert_numeric=True)
data1['A3_ratio'].convert_objects(convert_numeric=True)
data1['B1_ratio'].convert_objects(convert_numeric=True)
data1['B2_ratio'].convert_objects(convert_numeric=True)
data1['X1_ratio'].convert_objects(convert_numeric=True)
data1['X2_ratio'].convert_objects(convert_numeric=True)
# Out:
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:7: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# 0      0.170
# 1      0.170
# 2      0.170
# 3      0.170
# 4      0.170
# 5      0.170
# 6      0.170
# 7      0.170
# 8      0.170
# 9      0.170
# 10     0.170
# 11     0.170
# 12     0.170
# 13     0.170
# 14     0.170
# 15     0.170
# 16     0.170
# 17     0.170
# 18     0.170
# 19     0.170
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26     0.400
# 27       NaN
# 28     0.030
# 29     0.110
#        ...
# 192    0.333
# 193    0.333
# 194    0.500
# 195    0.500
# 196    0.500
# 197    0.500
# 198    0.500
# 199    0.500
# 200    0.500
# 201    0.667
# 202    0.667
# 203    0.667
# 204    0.667
# 205    0.667
# 206    0.667
# 207    0.667
# 208    0.833
# 209    0.833
# 210    0.833
# 211    0.833
# 212    0.833
# 213    0.833
# 214    0.833
# 215    1.000
# 216    1.000
# 217    1.000
# 218    1.000
# 219    1.000
# 220    1.000
# 221    1.000
# Name: X2_ratio, dtype: float64

# %%
data1 = data1.fillna(0)
data1
# Out:
#      A1 A1_ratio  A2 A2_ratio  A3 A3_ratio  B1 B1_ratio B2 B2_ratio X1  \
# 0    Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I
# 1    Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I
# 2    Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I
# 3    Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I
# 4    Cs     0.15  MA     0.85  FA     0.75  Pb        1  0        0  I
# 5    Cs     0.15  MA     0.85  FA     0.75  Pb        1  0        0  I
# 6    Cs     0.10  MA     0.90  FA     0.75  Pb        1  0        0  I
# 7    Cs     0.10  MA     0.90  FA     0.75  Pb        1  0        0  I
# 8    Cs     0.05  MA     0.95  FA     0.75  Pb        1  0        0  I
# 9     0        0  MA      1.0  FA     0.75  Pb        1  0        0  I
# 10   Cs      .17  MA     0.83  FA     0.83  Pb        1  0        0  I
# 11   Cs      .17  MA     0.83  FA     0.83  Pb        1  0        0  I
# 12   Cs      .14  MA     0.86  FA     0.83  Pb        1  0        0  I
# 13   Cs      .14  MA     0.86  FA     0.83  Pb        1  0        0  I
# 14   Cs      .10  MA     0.90  FA     0.83  Pb        1  0        0  I
# 15   Cs      .10  MA     0.90  FA     0.83  Pb        1  0        0  I
# 16   Cs      .05  MA     0.95  FA     0.83  Pb        1  0        0  I
# 17   Cs      .05  MA     0.95  FA     0.83  Pb        1  0        0  I
# 18    0        0  MA      1.0  FA     0.83  Pb        1  0        0  I
# 19    0        0  MA      1.0  FA     0.83  Pb        1  0        0  I
# 20    0        0  MA      1.0   0        0  Pb        1  0        0  I
# 21   Al    0.075  MA      1.0   0        0  Pb        1  0        0  I
# 22   Al     0.15  MA      1.0   0        0  Pb        1  0        0  I
# 23   Al      0.3  MA      1.0   0        0  Pb        1  0        0  I
# 24   Al     0.75  MA      1.0   0        0  Pb        1  0        0  I
# 25   Al      1.5  MA      1.0   0        0  Pb        1  0        0  I
# 26   FA     0.83  Cs     0.17   0        0  Pb        1  0        0  I
# 27   MA      1.0   0        0   0        0  Pb        1  0        0  I
# 28   MA      1.0   0        0   0        0  Pb        1  0        0  I
# 29   MA      1.0   0        0   0        0  Pb        1  0        0  I
# ..   ..      ...  ..      ...  ..      ...  ..      ... ..      ... ..
# 192  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 193  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 194  FA        1  MA        0   0        0  Pb        1  0        0  I
# 195  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 196  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 197  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 198  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 199  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 200  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 201  FA        1  MA        0   0        0  Pb        1  0        0  I
# 202  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 203  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 204  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 205  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 206  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 207  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 208  FA        1  MA        0   0        0  Pb        1  0        0  I
# 209  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 210  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 211  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 212  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 213  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 214  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 215  FA        1  MA        0   0        0  Pb        1  0        0  I
# 216  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 217  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 218  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 219  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 220  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 221  FA      0.0  MA        1   0        0  Pb        1  0        0  I
#
#     X1_ratio  X2 X2_ratio   PCE
# 0       0.83  Br     0.17  14.3
# 1       0.83  Br     0.17  12.4
# 2       0.83  Br     0.17  15.9
# 3       0.83  Br     0.17  15.2
# 4       0.83  Br     0.17  16.0
# 5       0.83  Br     0.17  16.8
# 6       0.83  Br     0.17  14.9
# 7       0.83  Br     0.17  16.3
# 8       0.83  Br     0.17   8.5
# 9       0.83  Br     0.17  10.1
# 10      0.83  Br     0.17  15.8
# 11      0.83  Br     0.17  15.4
# 12      0.83  Br     0.17  16.0
# 13      0.83  Br     0.17  16.3
# 14      0.83  Br     0.17  16.2
# 15      0.83  Br     0.17  16.2
# 16      0.83  Br     0.17  14.6
# 17      0.83  Br     0.17  15.5
# 18      0.83  Br     0.17  13.4
# 19      0.83  Br     0.17  12.9
# 20       1.0   0        0  13.2
# 21       1.0   0        0  13.6
# 22       1.0   0        0  15.8
# 23       1.0   0        0  14.2
# 24       1.0   0        0   9.8
# 25       1.0   0        0   5.5
# 26       0.6  Br      0.4  16.8
# 27       1.0   0        0   7.5
# 28      0.97   I     0.03  11.2
# 29      0.89   I     0.11  15.8
# ..       ...  ..      ...   ...
# 192    0.667  Br    0.333  12.2
# 193    0.667  Br    0.333   8.5
# 194      0.5  Br      0.5   3.7
# 195      0.5  Br      0.5  11.4
# 196      0.5  Br      0.5  11.7
# 197      0.5  Br      0.5  11.9
# 198      0.5  Br      0.5  10.7
# 199      0.5  Br      0.5   8.7
# 200      0.5  Br      0.5   8.6
# 201    0.333  Br    0.667   7.5
# 202    0.333  Br    0.667   5.8
# 203    0.333  Br    0.667   5.6
# 204    0.333  Br    0.667   7.9
# 205    0.333  Br    0.667   6.2
# 206    0.333  Br    0.667   3.5
# 207    0.333  Br    0.667   6.3
# 208    0.167  Br    0.833   5.0
# 209    0.167  Br    0.833   3.3
# 210    0.167  Br    0.833   3.4
# 211    0.167  Br    0.833   3.9
# 212    0.167  Br    0.833   2.9
# 213    0.167  Br    0.833   2.3
# 214    0.167  Br    0.833   3.5
# 215        0  Br      1.0   5.0
# 216        0  Br      1.0   6.5
# 217        0  Br      1.0   5.5
# 218        0  Br      1.0   7.1
# 219        0  Br      1.0   6.4
# 220        0  Br      1.0   7.1
# 221        0  Br      1.0   5.6
#
# [222 rows x 15 columns]

# %%
data1['A_sum'] = data1['A1_ratio'].convert_objects(convert_numeric=True)+data1['A2_ratio'].convert_objects(convert_numeric=True)+data1['A3_ratio'].convert_objects(convert_numeric=True)
data1['B_sum'] = data1['B1_ratio'].convert_objects(convert_numeric=True)+data1['B2_ratio'].convert_objects(convert_numeric=True)
data1['X_sum'] = data1['X1_ratio'].convert_objects(convert_numeric=True)+data1['X2_ratio'].convert_objects(convert_numeric=True)
# Out:
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# C:\Users\yongquan\Miniconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()

# %%
data1
# Out:
#      A1 A1_ratio  A2 A2_ratio  A3 A3_ratio  B1 B1_ratio B2 B2_ratio X1  \
# 0    Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I
# 1    Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I
# 2    Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I
# 3    Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I
# 4    Cs     0.15  MA     0.85  FA     0.75  Pb        1  0        0  I
# 5    Cs     0.15  MA     0.85  FA     0.75  Pb        1  0        0  I
# 6    Cs     0.10  MA     0.90  FA     0.75  Pb        1  0        0  I
# 7    Cs     0.10  MA     0.90  FA     0.75  Pb        1  0        0  I
# 8    Cs     0.05  MA     0.95  FA     0.75  Pb        1  0        0  I
# 9     0        0  MA      1.0  FA     0.75  Pb        1  0        0  I
# 10   Cs      .17  MA     0.83  FA     0.83  Pb        1  0        0  I
# 11   Cs      .17  MA     0.83  FA     0.83  Pb        1  0        0  I
# 12   Cs      .14  MA     0.86  FA     0.83  Pb        1  0        0  I
# 13   Cs      .14  MA     0.86  FA     0.83  Pb        1  0        0  I
# 14   Cs      .10  MA     0.90  FA     0.83  Pb        1  0        0  I
# 15   Cs      .10  MA     0.90  FA     0.83  Pb        1  0        0  I
# 16   Cs      .05  MA     0.95  FA     0.83  Pb        1  0        0  I
# 17   Cs      .05  MA     0.95  FA     0.83  Pb        1  0        0  I
# 18    0        0  MA      1.0  FA     0.83  Pb        1  0        0  I
# 19    0        0  MA      1.0  FA     0.83  Pb        1  0        0  I
# 20    0        0  MA      1.0   0        0  Pb        1  0        0  I
# 21   Al    0.075  MA      1.0   0        0  Pb        1  0        0  I
# 22   Al     0.15  MA      1.0   0        0  Pb        1  0        0  I
# 23   Al      0.3  MA      1.0   0        0  Pb        1  0        0  I
# 24   Al     0.75  MA      1.0   0        0  Pb        1  0        0  I
# 25   Al      1.5  MA      1.0   0        0  Pb        1  0        0  I
# 26   FA     0.83  Cs     0.17   0        0  Pb        1  0        0  I
# 27   MA      1.0   0        0   0        0  Pb        1  0        0  I
# 28   MA      1.0   0        0   0        0  Pb        1  0        0  I
# 29   MA      1.0   0        0   0        0  Pb        1  0        0  I
# ..   ..      ...  ..      ...  ..      ...  ..      ... ..      ... ..
# 192  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 193  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 194  FA        1  MA        0   0        0  Pb        1  0        0  I
# 195  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 196  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 197  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 198  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 199  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 200  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 201  FA        1  MA        0   0        0  Pb        1  0        0  I
# 202  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 203  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 204  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 205  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 206  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 207  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 208  FA        1  MA        0   0        0  Pb        1  0        0  I
# 209  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 210  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 211  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 212  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 213  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 214  FA      0.0  MA        1   0        0  Pb        1  0        0  I
# 215  FA        1  MA        0   0        0  Pb        1  0        0  I
# 216  FA    0.833  MA    0.167   0        0  Pb        1  0        0  I
# 217  FA    0.667  MA    0.333   0        0  Pb        1  0        0  I
# 218  FA     0.50  MA     0.50   0        0  Pb        1  0        0  I
# 219  FA    0.333  MA    0.667   0        0  Pb        1  0        0  I
# 220  FA    0.167  MA    0.167   0        0  Pb        1  0        0  I
# 221  FA      0.0  MA        1   0        0  Pb        1  0        0  I
#
#     X1_ratio  X2 X2_ratio   PCE  A_sum  B_sum  X_sum
# 0       0.83  Br     0.17  14.3  1.750    1.0    1.0
# 1       0.83  Br     0.17  12.4  1.750    1.0    1.0
# 2       0.83  Br     0.17  15.9  1.750    1.0    1.0
# 3       0.83  Br     0.17  15.2  1.750    1.0    1.0
# 4       0.83  Br     0.17  16.0  1.750    1.0    1.0
# 5       0.83  Br     0.17  16.8  1.750    1.0    1.0
# 6       0.83  Br     0.17  14.9  1.750    1.0    1.0
# 7       0.83  Br     0.17  16.3  1.750    1.0    1.0
# 8       0.83  Br     0.17   8.5  1.750    1.0    1.0
# 9       0.83  Br     0.17  10.1  1.750    1.0    1.0
# 10      0.83  Br     0.17  15.8  1.830    1.0    1.0
# 11      0.83  Br     0.17  15.4  1.830    1.0    1.0
# 12      0.83  Br     0.17  16.0  1.830    1.0    1.0
# 13      0.83  Br     0.17  16.3  1.830    1.0    1.0
# 14      0.83  Br     0.17  16.2  1.830    1.0    1.0
# 15      0.83  Br     0.17  16.2  1.830    1.0    1.0
# 16      0.83  Br     0.17  14.6  1.830    1.0    1.0
# 17      0.83  Br     0.17  15.5  1.830    1.0    1.0
# 18      0.83  Br     0.17  13.4  1.830    1.0    1.0
# 19      0.83  Br     0.17  12.9  1.830    1.0    1.0
# 20       1.0   0        0  13.2  1.000    1.0    1.0
# 21       1.0   0        0  13.6  1.075    1.0    1.0
# 22       1.0   0        0  15.8  1.150    1.0    1.0
# 23       1.0   0        0  14.2  1.300    1.0    1.0
# 24       1.0   0        0   9.8  1.750    1.0    1.0
# 25       1.0   0        0   5.5  2.500    1.0    1.0
# 26       0.6  Br      0.4  16.8  1.000    1.0    1.0
# 27       1.0   0        0   7.5  1.000    1.0    1.0
# 28      0.97   I     0.03  11.2  1.000    1.0    1.0
# 29      0.89   I     0.11  15.8  1.000    1.0    1.0
# ..       ...  ..      ...   ...    ...    ...    ...
# 192    0.667  Br    0.333  12.2  0.334    1.0    1.0
# 193    0.667  Br    0.333   8.5  1.000    1.0    1.0
# 194      0.5  Br      0.5   3.7  1.000    1.0    1.0
# 195      0.5  Br      0.5  11.4  1.000    1.0    1.0
# 196      0.5  Br      0.5  11.7  1.000    1.0    1.0
# 197      0.5  Br      0.5  11.9  1.000    1.0    1.0
# 198      0.5  Br      0.5  10.7  1.000    1.0    1.0
# 199      0.5  Br      0.5   8.7  0.334    1.0    1.0
# 200      0.5  Br      0.5   8.6  1.000    1.0    1.0
# 201    0.333  Br    0.667   7.5  1.000    1.0    1.0
# 202    0.333  Br    0.667   5.8  1.000    1.0    1.0
# 203    0.333  Br    0.667   5.6  1.000    1.0    1.0
# 204    0.333  Br    0.667   7.9  1.000    1.0    1.0
# 205    0.333  Br    0.667   6.2  1.000    1.0    1.0
# 206    0.333  Br    0.667   3.5  0.334    1.0    1.0
# 207    0.333  Br    0.667   6.3  1.000    1.0    1.0
# 208    0.167  Br    0.833   5.0  1.000    1.0    1.0
# 209    0.167  Br    0.833   3.3  1.000    1.0    1.0
# 210    0.167  Br    0.833   3.4  1.000    1.0    1.0
# 211    0.167  Br    0.833   3.9  1.000    1.0    1.0
# 212    0.167  Br    0.833   2.9  1.000    1.0    1.0
# 213    0.167  Br    0.833   2.3  0.334    1.0    1.0
# 214    0.167  Br    0.833   3.5  1.000    1.0    1.0
# 215        0  Br      1.0   5.0  1.000    1.0    1.0
# 216        0  Br      1.0   6.5  1.000    1.0    1.0
# 217        0  Br      1.0   5.5  1.000    1.0    1.0
# 218        0  Br      1.0   7.1  1.000    1.0    1.0
# 219        0  Br      1.0   6.4  1.000    1.0    1.0
# 220        0  Br      1.0   7.1  0.334    1.0    1.0
# 221        0  Br      1.0   5.6  1.000    1.0    1.0
#
# [222 rows x 18 columns]

# %%
data1.loc[data1['A_sum']!=1].head()
# Out:
#    A1 A1_ratio  A2 A2_ratio  A3 A3_ratio  B1 B1_ratio B2 B2_ratio X1 X1_ratio  \
# 0  Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I     0.83
# 1  Cs      .25  MA     0.75  FA     0.75  Pb        1  0        0  I     0.83
# 2  Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I     0.83
# 3  Cs     0.21  MA     0.79  FA     0.75  Pb        1  0        0  I     0.83
# 4  Cs     0.15  MA     0.85  FA     0.75  Pb        1  0        0  I     0.83
#
#    X2 X2_ratio   PCE  A_sum  B_sum  X_sum
# 0  Br     0.17  14.3   1.75    1.0    1.0
# 1  Br     0.17  12.4   1.75    1.0    1.0
# 2  Br     0.17  15.9   1.75    1.0    1.0
# 3  Br     0.17  15.2   1.75    1.0    1.0
# 4  Br     0.17  16.0   1.75    1.0    1.0

# %%
data1.loc[data1['B_sum']!=1].head()
# Out:
# Empty DataFrame
# Columns: [A1, A1_ratio, A2, A2_ratio, A3, A3_ratio, B1, B1_ratio, B2, B2_ratio, X1, X1_ratio, X2, X2_ratio, PCE, A_sum, B_sum, X_sum]
# Index: []

# %%
data1.loc[data1['X_sum']!=1].head()
# Out:
#     A1 A1_ratio  A2 A2_ratio A3 A3_ratio  B1 B1_ratio  B2 B2_ratio X1  \
# 32  FA     0.95  MA      0.5  0        0  Pb        1   0        0  I
# 37  MA      1.0   0        0  0        0  Pb     0.97  Sn     0.03  I
# 38  MA      1.0   0        0  0        0  Pb     0.95  Sn     0.05  I
# 39  MA      1.0   0        0  0        0  Pb     0.90  Sn     0.10  I
# 40  MA     0.95  Cs     0.05  0        0  Pb     0.95  Sn     0.05  I
#
#    X1_ratio  X2 X2_ratio    PCE  A_sum  B_sum  X_sum
# 32     0.95  Br      0.5  10.10   1.45    1.0   1.45
# 37     2.94  Br     0.06   5.24   1.00    1.0   3.00
# 38     2.90  Br     0.10   7.59   1.00    1.0   3.00
# 39     2.80  Br     0.20   4.74   1.00    1.0   3.00
# 40     2.90  Br     0.10   8.25   1.00    1.0   3.00

# %%
Cl = {'IR':181, 'EA':3.61, 'IE':12.97, 'IP':16.0858, 'AP':11.5582}
Br = {'IR':196, 'EA':3.36, 'IE':11.81, 'IP':20.5166, 'AP':15.4074}
I = {'IR':220, 'EA':3.06, 'IE':10.45, 'IP':43.2951, 'AP':28.8659}
Al = {'IR': 53.5, 'EA':0.43, 'IE':5.99, 'IP':25.6499, 'AP':46.2}
Cs = {'IR':167, 'EA':0.47, 'IE':3.89, 'IP':15.544, 'AP':402}
Rb = {'IR':152, 'EA':0.486, 'IE':4.18, 'IP':9, 'AP':319}
Pb = {'IR':133, 'EA':0.37, 'IE':7.42, 'IP':13.8008, 'AP':47.1}
Sn = {'IR':83, 'EA':1.11, 'IE':7.34, 'IP':15.5813, 'AP':42.4}
Ge = {'IR':87, 'EA':1.23, 'IE':7.899, 'IP':11.3784, 'AP':30.9097}
Sr = {'IR':132, 'EA':0.05, 'IE':5.69, 'IP':5.792, 'AP':186}
Ni = {'IR':83, 'EA':1.16, 'IE':7.64, 'IP':0.0, 'AP':0.0} # missiing data
Mg = {'IR':86, 'EA':0.0, 'IE':7.65, 'IP':0.489, 'AP':71.33} # missiing data
Fe = {'IR':75, 'EA':0.31, 'IE':7.90, 'IP':0.0, 'AP':0.0} # missiing data
Cu = {'IR':87, 'EA':1.24, 'IE':7.73, 'IP':0.0, 'AP':41.65} # missiing data
Co = {'IR':79, 'EA':0.6633, 'IE':7.88, 'IP':0.0, 'AP':0.0} # missiing data
MA = {'IR':537, 'EA':0.80, 'IE':10.66, 'IP':19.7942, 'AP':25.1017}
FA = {'IR':641, 'EA':0.60, 'IE':10.03, 'IP':26.8527, 'AP':32.5342}
HA = {'IR':523, 'EA':0.89, 'IE':9.90, 'IP':17.4412, 'AP':22.566}
Mn = {'IR':82, 'EA':8.26343, 'IE':7.434, 'IP':0.0, 'AP':0.0} # EA = proton affinity, IP and AP not defined yet
Zn = {'IR':131, 'EA':6.3077, 'IE':9.394, 'IP':0.0, 'AP':0.0} # EA = proton affinity, IP and AP not defined yet
NL = {'IR':0.0, 'EA':0.0, 'IE':0.0, 'IP':0.0, 'AP':0.0}

# %%
B_site = np.random.rand(222)
for i in range(222):
    if(type(data1['B1'].loc[i])==str):
        tmp1 = eval(data1['B1'].loc[i])
    else:
        tmp1 = eval('NL')
    if(type(data1['B2'].loc[i])==str):
        tmp2 = eval(data1['B2'].loc[i])
    else:
        tmp2 = eval('NL')
    B_site[i] = tmp1['IE']*float(data1['B1_ratio'].loc[i])+tmp2['IE']*float(data1['B2_ratio'].loc[i])

# %%
# PCE vs. IE
plt.scatter(B_site,data1['PCE'])

# %%
B_site = np.random.rand(222)
for i in range(222):
    if(type(data1['B1'].loc[i])==str):
        tmp1 = eval(data1['B1'].loc[i])
    else:
        tmp1 = eval('NL')
    if(type(data1['B2'].loc[i])==str):
        tmp2 = eval(data1['B2'].loc[i])
    else:
        tmp2 = eval('NL')
    B_site[i] = tmp1['EA']*float(data1['B1_ratio'].loc[i])+tmp2['EA']*float(data1['B2_ratio'].loc[i])

# %%
# PCE vs. EA
plt.scatter(B_site,data1['PCE'])
